# %%
from ultralytics import YOLO

model = YOLO('yolov8n.pt')  # load a pretrained YOLOv8n detection model
model.train(data='/home/pc47/Documents/CE339_2021538/ds_173_538_project/Sign_language_data/data.yaml', epochs=1)
# Out:
# New https://pypi.org/project/ultralytics/8.2.11 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.2 🚀 Python-3.11.4 torch-2.2.2+cu121 CPU (11th Gen Intel Core(TM) i7-11700 2.50GHz)
# ...

# %%
model('/home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images')  # predict on an image
# Out:
# image 1/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.82af5cd8-a6d1-11ec-a2fc-84a93ea18ae6.jpg: 480x640 1 Hello, 31.6ms
# image 2/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6 - Copy.jpg: 480x640 (no detections), 30.4ms
# image 3/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6.jpg: 480x640 (no detections), 34.6ms
# image 4/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8c5b98c8-a6d1-11ec-a905-84a93ea18ae6.jpg: 480x640 (no detections), 36.6ms
# ...

# %%
model('/home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images')  # predict on an image
# Out:
# image 1/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.82af5cd8-a6d1-11ec-a2fc-84a93ea18ae6.jpg: 480x640 1 Hello, 37.9ms
# image 2/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6 - Copy.jpg: 480x640 1 Hello, 28.6ms
# image 3/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8b2540a6-a6d1-11ec-a828-84a93ea18ae6.jpg: 480x640 1 Hello, 28.3ms
# image 4/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8c5b98c8-a6d1-11ec-a905-84a93ea18ae6.jpg: 480x640 1 Hello, 28.2ms
# image 5/30 /home/pc47/Documents/CE339_2021538/Lab10/Weapons-and-Knives-Detector-with-YOLOv8/Sign_language_data/test/images/Hello.8d922278-a6d1-11ec-9c17-84a93ea18ae6.jpg: 480x640 1 Hello, 28.1ms
# ...

# %%
sudo apt install libgtk2.0-dev pkg-config
# Out:
#   Cell In [4], line 1
#     sudo apt install libgtk2.0-dev pkg-config
#          ^
# SyntaxError: invalid syntax

# %%
from ultralytics import YOLO

import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results
def draw_landmarks(image, results):
    mp_holistic = mp.solutions.holistic  # Holistic model
    mp_drawing = mp.solutions.drawing_utils  # Drawing utilities
    # Draw left hand connections
    image = mp_drawing.draw_landmarks(
            image,
            landmark_list=results.left_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing.DrawingSpec(
                color=(232, 254, 255), thickness=1, circle_radius=4
            ),
            connection_drawing_spec=mp_drawing.DrawingSpec(
                color=(255, 249, 161), thickness=2, circle_radius=2
            ),
    )
    # Draw right hand connections
    image = mp_drawing.draw_landmarks(
            image,
            landmark_list=results.right_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing.DrawingSpec(
                color=(232, 254, 255), thickness=1, circle_radius=4
            ),
            connection_drawing_spec=mp_drawing.DrawingSpec(
                color=(255, 249, 161), thickness=2, circle_radius=2
            ),
    )


image, results=mediapipe_detection(cap.read(),model)
draw_landmarka(image,results)

# object classes
classNames = ['Hello', 'IloveYou', 'No', 'Please', 'Thanks', 'Yes']


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])
            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# [ WARN:0@443.481] global cap_v4l.cpp:997 open VIDEOIO(V4L2:/dev/video0): can't open camera by index
# [ERROR:0@443.481] global obsensor_uvc_stream_channel.cpp:159 getStreamChannelGroup Camera index out of range
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [5], line 46
#      32     # Draw right hand connections
#      33     image = mp_drawing.draw_landmarks(
#      34             image,
#      35             landmark_list=results.right_hand_landmarks,
#    (...)
#      42             ),
#      43     )
# ---> 46 image, results=mediapipe_detection(cap.read(),model)
#      47 draw_landmarka(image,results)
#      49 # object classes
#
# Cell In [5], line 11, in mediapipe_detection(image, model)
#      10 def mediapipe_detection(image, model):
# ---> 11     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#      12     image.flags.writeable = False
# ...

# %%
def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results
def draw_landmarks(image, results):
    mp_holistic = mp.solutions.holistic  # Holistic model
    mp_drawing = mp.solutions.drawing_utils  # Drawing utilities
    # Draw left hand connections
    image = mp_drawing.draw_landmarks(
            image,
            landmark_list=results.left_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing.DrawingSpec(
                color=(232, 254, 255), thickness=1, circle_radius=4
            ),
            connection_drawing_spec=mp_drawing.DrawingSpec(
                color=(255, 249, 161), thickness=2, circle_radius=2
            ),
    )
    # Draw right hand connections
    image = mp_drawing.draw_landmarks(
            image,
            landmark_list=results.right_hand_landmarks,
            connections=mp_holistic.HAND_CONNECTIONS,
            landmark_drawing_spec=mp_drawing.DrawingSpec(
                color=(232, 254, 255), thickness=1, circle_radius=4
            ),
            connection_drawing_spec=mp_drawing.DrawingSpec(
                color=(255, 249, 161), thickness=2, circle_radius=2
            ),
    )

# %%
pip install mediapipe as mp
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as
# Note: you may need to restart the kernel to use updated packages.
